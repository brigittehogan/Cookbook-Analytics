# %% [markdown]
# # TFIDF
# - Brigitte Hogan (bwh5v@virginia.edu) & Jason Tiezzi (jbt5am@virginia.edu)
# - DS 5001: Exploratory Text Analytics
# - April 2020

# %% [markdown]
# <font color = gray>
#
# ## Overview
#
# This notebook creates 3 TFIDF tables for our corpus:
#
#     1. TFIDF with bag of Recipe (TFIDF_recipe.csv)
#
#     2. TFIDF with bag of Book (`TFIDF_book.csv`)
#
#     3. TFIDF with bag of Period (`'TFIDF_timeperiod.csv'`)

# %% [markdown]
# ---
# # Setup

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly_express as px
from nltk.stem.porter import PorterStemmer
import os

# %% [markdown]
# ## Configs

# %%
#os.chdir('C:/Users/Jason/Documents/Data Science/Spring 2020/Text Analytics/final_project/DS5001-Text-Analytics/')
file_dir = 'C:/Users/Jason/Documents/Data Science/Spring 2020/Text Analytics/final_project/DS5001-Text-Analytics/'
data_dir = 'Tables/'
os.chdir(file_dir)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Defining the TFIDF Function

# %%
def TFIDF(TOKEN, OHCO='book', count_method='n', tf_method='sum', idf_method='standard', term_type='term_str'): 

    #specifying the term type
    TOKEN = TOKEN[~TOKEN.term_str.isna()] #removing blank term_str
    stemmer1 = PorterStemmer()
    TOKEN['stem'] = TOKEN.term_str.apply(stemmer1.stem) #adding stems
    print('Term Type: ', term_type)

    
    #specifying the bag size, customized to our text
    OHCO1 = ['period', 'book_year','book_id', 'vol_num','chap_num', 'recp_num','para_num', 'sent_num', 'token_num']
    sentence = OHCO1[:8]
    paragraph = OHCO1[:7]
    recipe = OHCO1[:6]
    chapter = OHCO1[:5]
    volume = OHCO1[:4]
    book = OHCO1[:3]
    book_year = OHCO1[:2]
    period = OHCO1[:1]
    if OHCO == 'chapter':
        bag = chapter
    elif OHCO == 'sentence':
        bag = sentence
    elif OHCO == 'paragraph':
        bag = paragraph
    elif OHCO == 'book':
        bag = book
    elif OHCO == 'recipe':
        bag = recipe
    elif OHCO == 'volume':
        bag = volume
    elif OHCO == 'period':
        bag = period
    elif OHCO == 'book_year':
        bag = book_year
    print('Bag Level: ', OHCO)

    #creating the document-term matrix
    BOW = TOKEN.groupby(bag+[term_type]).term_str.count()\
    .to_frame().rename(columns={'term_str':'n'})
    BOW['c'] = BOW.n.astype('bool').astype('int')
    DTCM = BOW[count_method].unstack().fillna(0).astype('int')
    print('Count method: ', count_method)

    #specifying the TF method and calculating TF
    if tf_method == 'sum':
        TF = DTCM.T / DTCM.T.sum()
    elif tf_method == 'max':
        TF = DTCM.T / DTCM.T.max()
    elif tf_method == 'log':
        TF = np.log10(1 + DTCM.T)
    elif tf_method == 'raw':
        TF = DTCM.T
    elif tf_method == 'double_norm':
        TF = DTCM.T / DTCM.T.max()
        TF = tf_norm_k + (1 - tf_norm_k) * TF[TF > 0] 
    elif tf_method == 'binary':
        TF = DTCM.T.astype('bool').astype('int')
    print('TF method: ', tf_method)
   
    #calculating DF and TFIDF
    DF = DTCM[DTCM > 0].count()
    N = DTCM.shape[0]
    
    if idf_method == 'standard':
        IDF = np.log10(N / DF)
    elif idf_method == 'max':
        IDF = np.log10(DF.max() / DF) 
    elif idf_method == 'smooth':
        IDF = np.log10((1 + N) / (1 + DF)) + 1 
    print('IDF method: ', idf_method)    

    TF = TF.T
    TFIDF = TF * IDF
    
    return TFIDF

# %% [markdown]
# ---
# # Calculating TFIDF for our corpus

# %% [markdown]
# ### Reading in the data and preprocessing

# %%
TOKEN = pd.read_csv(data_dir + 'TOKEN.csv')

# %%
TOKEN.sample(20, random_state=2887)
# Out:
#          book_id  vol_num  chap_num  recp_num  para_num  sent_num  token_num  \
# 1002620    54568        2        16     157.0         1         3         10
# 702288     28681        2         8       0.0        12         0         29
# 325684      9938        3       156     269.0         1         1         27
# 113804      9936        2        30      84.0         0         6          5
# 747960     28681        3        24      18.0        52         0         12
# 268429      9937        5       208     408.0         0         4          0
# 1034432    54568        2        29     289.0         7         1         52
# 281432      9938        1         6      19.0         0         3         14
# 30538       9935        2        51     135.0         0         4         25
# 886083     28681        5        37      37.0        32         0          6
# 699094     28681        2         6       0.0        24         1          7
# 63861       9935        4       150     274.0         1         1         46
# 877272     28681        4        34      31.0        28         3         13
# 1094623    61185        0        10       0.0        28         0         20
# 522782     12519        0         5      64.0         1         0          5
# 545906     12519        0        11     266.0         1         0         95
# 456271      9939        4       197     517.0         9         2          3
# 55595       9935        3       130     240.0         0         1          3
# 892012     29519        0         2      20.0         1         4         13
# 7302        9935        1        11      34.0         0         2         35
#
#                  pos_tuple  pos token_str term_str
# 1002620     ('time', 'NN')   NN      time     time
# 702288        ('up', 'RP')   RP        up       up
# 325684       ('all', 'DT')   DT       all      all
# 113804          (',', ',')    ,         ,      NaN
# 747960        ('No', 'UH')   UH        No       no
# 268429   ('Besides', 'IN')   IN   Besides  besides
# 1034432    ('aside', 'RB')   RB     aside    aside
# 281432     ('serve', 'VB')   VB     serve    serve
# 30538       ('that', 'IN')   IN      that     that
# 886083     ('light', 'JJ')   JJ     light    light
# 699094         ('7', 'CD')   CD         7        7
# 63861           (',', ',')    ,         ,      NaN
# 877272          (';', ':')    :         ;      NaN
# 1094623       ('by', 'IN')   IN        by       by
# 522782      ('take', 'VB')   VB      take     take
# 545906       ('the', 'DT')   DT       the      the
# 456271        ('to', 'TO')   TO        to       to
# 55595       ('AND', 'NNP')  NNP       AND      and
# 892012   ('lobster', 'NN')   NN   lobster  lobster
# 7302       ('clear', 'JJ')   JJ     clear    clear

# %%
TOKEN.shape
# Out:
# (1130904, 11)

# %%
LIB = pd.read_csv(data_dir + 'LIB.csv')
LIB
# Out:
#     book_id          author_last  \
# 0      9935      Cookbooks\WIDAS
# 1      9936      Cookbooks\WIDAS
# 2      9937      Cookbooks\WIDAS
# 3      9938      Cookbooks\WIDAS
# 4      9939      Cookbooks\WIDAS
# 5     10582    Cookbooks\Bradley
# 6     12519    Cookbooks\Randolf
# 7     15464    Cookbooks\Goudiss
# 8     19077       Cookbooks\Hill
# 9     24205     Cookbooks\Murrey
# 10    24542     Cookbooks\Murrey
# 11    25007     Cookbooks\Murrey
# 12    28681  Cookbooks\Kitchiner
# 13    29519     Cookbooks\Hooper
# 14    32472       Cookbooks\Lusk
# 15    34107  Cookbooks\Santiagoe
# 16    38464     Cookbooks\Murrey
# 17    53521     Cookbooks\Murrey
# 18    54568     Cookbooks\Boland
# 19    61185      Cookbooks\Payne
#
#                                         author_full  book_year  \
# 0   Woman's Institute of Domestic Arts and Sciences       1923
# 1   Woman's Institute of Domestic Arts and Sciences       1923
# 2   Woman's Institute of Domestic Arts and Sciences       1923
# 3   Woman's Institute of Domestic Arts and Sciences       1923
# 4   Woman's Institute of Domestic Arts and Sciences       1923
# 5                                     Alice Bradley       1923
# 6                                     Mary Randolph       1860
# 7                                     Alice Bradley       1918
# 8                               Janet McKenzie Hill       1909
# 9                                  Thomas J. Murrey       1885
# 10                                 Thomas J. Murrey       1885
# 11                                 Thomas J. Murrey       1884
# 12                                William Kitchiner       1830
# 13                                      Mary Hooper       1892
# 14                                      Graham Lusk       1918
# 15                                 Daniel Santiagoe       1887
# 16                                 Thomas J. Murrey       1891
# 17                                 Thomas J. Murrey       1888
# 18                                   Mary A. Boland       1893
# 19                                 Arthur Gay Payne       1877
#
#                                         book_title  \
# 0     Woman's Institute Library of Cookery, Vol. 1
# 1     Woman's Institute Library of Cookery, Vol. 2
# 2     Woman's Institute Library of Cookery, Vol. 3
# 3     Woman's Institute Library of Cookery, Vol. 4
# 4     Woman's Institute Library of Cookery, Vol. 5
# 5                   For Luncheon and Supper Guests
# 6                           The Virginia Housewife
# 7      Foods That Will Win The War And How To Cook
# 8   Salads, Sandwiches and Chafing - Dish Dainties
# 9                               Breakfast Dainties
# 10                                    Fifty Salads
# 11                                     Fifty Soups
# 12     The Cook's Oracle; and Housekeeper's Manual
# 13                          Nelson's Home Comforts
# 14                                Food in War Time
# 15                      The Curry Cook's Assistant
# 16                           Tempting Curry Dishes
# 17                                Oysters and Fish
# 18                   A Handbook of Invalid Cooking
# 19                Common - Sense Papers on Cookery
#
#                                         book_file     period
# 0          Cookbooks\WIDAS1923_WILCV01_pg9935.txt      1900s
# 1          Cookbooks\WIDAS1923_WILCV02_pg9936.txt      1900s
# 2          Cookbooks\WIDAS1923_WILCV03_pg9937.txt      1900s
# 3          Cookbooks\WIDAS1923_WILCV04_pg9938.txt      1900s
# 4          Cookbooks\WIDAS1923_WILCV05_pg9939.txt      1900s
# 5          Cookbooks\Bradley1923_FLSG_pg10582.txt      1900s
# 6   Cookbooks\Randolf1860_VAHousewife_pg12519.txt   mid1800s
# 7           Cookbooks\Goudiss1918_War_pg15464.txt      1900s
# 8            Cookbooks\Hill1909_SSCDD_pg19077.txt      1900s
# 9          Cookbooks\Murrey1885_Bfast_pg24205.txt  late1800s
# 10        Cookbooks\Murrey1885_Salads_pg24542.txt  late1800s
# 11         Cookbooks\Murrey1884_Soups_pg25007.txt  late1800s
# 12        Cookbooks\Kitchiner1830_TCO_pg28681.txt   mid1800s
# 13           Cookbooks\Hooper1892_NHC_pg29519.txt  late1800s
# 14             Cookbooks\Lusk1918_War_pg32472.txt      1900s
# 15      Cookbooks\Santiagoe1887_Curry_pg34107.txt  late1800s
# 16         Cookbooks\Murrey1891_Curry_pg38464.txt  late1800s
# 17          Cookbooks\Murrey1888_Fish_pg53521.txt  late1800s
# 18       Cookbooks\Boland1893_Invalid_pg54568.txt  late1800s
# 19           Cookbooks\Payne1877_CSPC_pg61185.txt  late1800s

# %%
VOCAB = pd.read_csv(data_dir + 'VOCAB.csv')
VOCAB.head()
# Out:
#    term_id term_str  Unnamed: 2     n  num  has_int  stop stem_porter  \
# 0        1        0         NaN    69    1        1     0           0
# 1        2        0         NaN     1    1        1     0           0
# 2       14        1         NaN  4035    1        1     0           1
# 3        3        1         NaN     1    1        1     0           1
# 4        5        1         NaN     1    1        1     0           1
#
#   stem_snowball
# 0             0
# 1             0
# 2             1
# 3             1
# 4             1

# %% [markdown]
# ### Merging in the library table since it contains the book year and period

# %%
TOKEN1 = pd.merge(TOKEN,LIB,on='book_id', how="inner")
TOKEN1.sample(10)
# Out:
#          book_id  vol_num  chap_num  recp_num  para_num  sent_num  token_num  \
# 1123186    61185        0        18       0.0        10         9         15
# 634933     19077        3        22     311.0         1         0          9
# 603049     19077        1         5      49.0         3         1          6
# 932555     34107        0         0       6.0         1         4         27
# 90679       9935        5       222     390.0         0         4          8
# 217128      9937        2        85     142.0         1         0         11
# 45824       9935        3        89     189.0         2         1          1
# 1060491    54568        2        36     376.0         1         3         36
# 250328      9937        3       166     314.0         1         6         19
# 812053     28681        3        28      22.0       189         0         66
#
#                 pos_tuple  pos token_str term_str          author_last  \
# 1123186       ('a', 'DT')   DT         a        a      Cookbooks\Payne
# 634933    ('quick', 'JJ')   JJ     quick    quick       Cookbooks\Hill
# 603049       ('of', 'IN')   IN        of       of       Cookbooks\Hill
# 932555      ('it', 'PRP')  PRP        it       it  Cookbooks\Santiagoe
# 90679     ('sharp', 'JJ')   JJ     sharp    sharp      Cookbooks\WIDAS
# 217128        ('a', 'DT')   DT         a        a      Cookbooks\WIDAS
# 45824       ('add', 'VB')   VB       add      add      Cookbooks\WIDAS
# 1060491        ('.', '.')    .         .      NaN     Cookbooks\Boland
# 250328   ('tender', 'NN')   NN    tender   tender      Cookbooks\WIDAS
# 812053     ('will', 'MD')   MD      will     will  Cookbooks\Kitchiner
#
#                                              author_full  book_year  \
# 1123186                                 Arthur Gay Payne       1877
# 634933                               Janet McKenzie Hill       1909
# 603049                               Janet McKenzie Hill       1909
# 932555                                  Daniel Santiagoe       1887
# 90679    Woman's Institute of Domestic Arts and Sciences       1923
# 217128   Woman's Institute of Domestic Arts and Sciences       1923
# 45824    Woman's Institute of Domestic Arts and Sciences       1923
# 1060491                                   Mary A. Boland       1893
# 250328   Woman's Institute of Domestic Arts and Sciences       1923
# 812053                                 William Kitchiner       1830
#
#                                              book_title  \
# 1123186                Common - Sense Papers on Cookery
# 634933   Salads, Sandwiches and Chafing - Dish Dainties
# 603049   Salads, Sandwiches and Chafing - Dish Dainties
# 932555                       The Curry Cook's Assistant
# 90679      Woman's Institute Library of Cookery, Vol. 1
# 217128     Woman's Institute Library of Cookery, Vol. 3
# 45824      Woman's Institute Library of Cookery, Vol. 1
# 1060491                   A Handbook of Invalid Cooking
# 250328     Woman's Institute Library of Cookery, Vol. 3
# 812053      The Cook's Oracle; and Housekeeper's Manual
#
#                                          book_file     period
# 1123186       Cookbooks\Payne1877_CSPC_pg61185.txt  late1800s
# 634933        Cookbooks\Hill1909_SSCDD_pg19077.txt      1900s
# 603049        Cookbooks\Hill1909_SSCDD_pg19077.txt      1900s
# 932555   Cookbooks\Santiagoe1887_Curry_pg34107.txt  late1800s
# 90679       Cookbooks\WIDAS1923_WILCV01_pg9935.txt      1900s
# 217128      Cookbooks\WIDAS1923_WILCV03_pg9937.txt      1900s
# 45824       Cookbooks\WIDAS1923_WILCV01_pg9935.txt      1900s
# 1060491   Cookbooks\Boland1893_Invalid_pg54568.txt  late1800s
# 250328      Cookbooks\WIDAS1923_WILCV03_pg9937.txt      1900s
# 812053     Cookbooks\Kitchiner1830_TCO_pg28681.txt   mid1800s

# %% [markdown]
# ## Applying the Function

# %% [markdown]
# ### Running the function with a bag of book
#
# Note: I defined all of the arguments (even though it's not required by the function) just so it would be clear what specifications we used.

# %%
TFIDF_book = TFIDF(TOKEN=TOKEN1, OHCO='book', count_method='n', tf_method='sum', idf_method='standard', term_type='term_str')
# Out:
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Term Type:  term_str
# Bag Level:  book
# Count method:  n
# TF method:  sum
# IDF method:  standard

# %%
TFIDF_book.sum().sort_values(ascending=False).head(30)

#looking at the top 30 words in our corpus by TFIDF -- interesting that we got some numbers in there!
# Out:
# term_str
# 12               0.010532
# 1                0.009640
# curry            0.008969
# teaspoon         0.008843
# tablespoons      0.007332
# tsp              0.006166
# antonini         0.005320
# cup              0.005207
# 14               0.005086
# c                0.004756
# p                0.004661
# nelson           0.004642
# tb               0.004391
# smith            0.003997
# metabolism       0.003850
# tablespoon       0.003781
# teaspoons        0.003732
# syrup            0.003596
# j                0.003342
# 4                0.003191
# stuffs           0.003133
# blazer           0.003121
# till             0.003036
# calories         0.002940
# madras           0.002933
# teaspoonful      0.002919
# foods            0.002870
# gill             0.002839
# 3                0.002827
# tablespoonful    0.002749
# dtype: float64

# %%
sumsb = pd.DataFrame(TFIDF_book.sum(), columns=['TFIDF_sum_book'])
VOCAB = pd.merge(VOCAB, sumsb, on='term_str') #adding the TFIDF sums to the book
VOCAB.head()
# Out:
#    term_id term_str  Unnamed: 2     n  num  has_int  stop stem_porter  \
# 0        1        0         NaN    69    1        1     0           0
# 1        2        0         NaN     1    1        1     0           0
# 2       14        1         NaN  4035    1        1     0           1
# 3        3        1         NaN     1    1        1     0           1
# 4        5        1         NaN     1    1        1     0           1
#
#   stem_snowball  TFIDF_sum_book
# 0             0        0.000595
# 1             0        0.000595
# 2             1        0.009640
# 3             1        0.009640
# 4             1        0.009640

# %% [markdown]
# ### Running TFIDF with a bag of recipe

# %%
TFIDF_recp = TFIDF(TOKEN=TOKEN1, OHCO='recipe', count_method='n', tf_method='sum', idf_method='standard', term_type='term_str')
# Out:
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Term Type:  term_str
# Bag Level:  recipe
# Count method:  n
# TF method:  sum
# IDF method:  standard

# %%
TFIDF_recp.sum().sort_values(ascending=False).head(30)
#looking at TFIDF by recipe
# Out:
# term_str
# 1         25.807714
# is        18.428777
# cup       18.059645
# it        17.931239
# them      17.303845
# be        16.731512
# are       16.177557
# c         16.170029
# 2         16.137305
# milk      16.041030
# water     15.611171
# 12        15.214541
# as        15.057910
# add       15.005058
# the       14.919713
# sugar     14.177607
# butter    13.546018
# for       13.489683
# that      13.470927
# cream     13.446396
# of        13.203503
# or        13.176509
# with      13.100030
# salt      13.007485
# they      12.901848
# a         12.451291
# flour     12.357812
# salad     12.221847
# to        11.958100
# sauce     11.916914
# dtype: float64

# %%
sumsr = pd.DataFrame(TFIDF_recp.sum(), columns=['TFIDF_sum_recipe'])
VOCAB = pd.merge(VOCAB, sumsr, on='term_str') #adding the TFIDF sums to the book
VOCAB.head()
# Out:
#    term_id term_str  Unnamed: 2     n  num  has_int  stop stem_porter  \
# 0        1        0         NaN    69    1        1     0           0
# 1        2        0         NaN     1    1        1     0           0
# 2       14        1         NaN  4035    1        1     0           1
# 3        3        1         NaN     1    1        1     0           1
# 4        5        1         NaN     1    1        1     0           1
#
#   stem_snowball  TFIDF_sum_book  TFIDF_sum_recipe
# 0             0        0.000595          0.137477
# 1             0        0.000595          0.137477
# 2             1        0.009640         25.807714
# 3             1        0.009640         25.807714
# 4             1        0.009640         25.807714

# %% [markdown]
# ### Running TFIDF with a bag of book period

# %%
TFIDF_timeperiod = TFIDF(TOKEN1, OHCO="period", count_method='n', tf_method='sum', idf_method='standard', term_type='term_str')
# Out:
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Term Type:  term_str
# Bag Level:  period
# Count method:  n
# TF method:  sum
# IDF method:  standard

# %%
TFIDF_timeperiod.sum().sort_values(ascending=False).head(30)
# Out:
# term_str
# tsp               0.000777
# obs               0.000682
# tb                0.000554
# flavor            0.000335
# teaspoon          0.000299
# nelson            0.000291
# sirup             0.000282
# amount            0.000252
# teaspoonful       0.000228
# tablespoons       0.000191
# yelks             0.000184
# nb                0.000172
# shown             0.000168
# etc               0.000162
# tablespoonful     0.000156
# tablespoon        0.000149
# qt                0.000145
# color             0.000142
# canned            0.000141
# colour            0.000135
# protein           0.000133
# yelk              0.000132
# yolks             0.000127
# saltspoon         0.000122
# tablespoonfuls    0.000120
# tamis             0.000115
# ¼                 0.000109
# mayonnaise        0.000108
# drachm            0.000108
# savoury           0.000106
# dtype: float64

# %%
sumsp = pd.DataFrame(TFIDF_timeperiod.sum(), columns=['TFIDF_sum_period'])
VOCAB = pd.merge(VOCAB, sumsp, on='term_str') #adding the TFIDF sums to the book
VOCAB.head()
# Out:
#    term_id term_str  Unnamed: 2     n  num  has_int  stop stem_porter  \
# 0        1        0         NaN    69    1        1     0           0
# 1        2        0         NaN     1    1        1     0           0
# 2       14        1         NaN  4035    1        1     0           1
# 3        3        1         NaN     1    1        1     0           1
# 4        5        1         NaN     1    1        1     0           1
#
#   stem_snowball  TFIDF_sum_book  TFIDF_sum_recipe  TFIDF_sum_period
# 0             0        0.000595          0.137477          0.000053
# 1             0        0.000595          0.137477          0.000053
# 2             1        0.009640         25.807714          0.000000
# 3             1        0.009640         25.807714          0.000000
# 4             1        0.009640         25.807714          0.000000

# %% [markdown]
# ---
# # Writing to CSV

# %%
#TFIDF_book.to_csv(data_dir + 'TFIDF_book.csv')
#TFIDF_recp.to_csv(data_dir + 'TFIDF_recp.csv')
#TFIDF_timeperiod.to_csv(data_dir + 'TFIDF_timeperiod.csv')
#VOCAB.to_csv(data_dir + 'VOCAB.csv')
