# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly_express as px
from nltk.stem.porter import PorterStemmer
import os

# %% [markdown]
# # Calculating TFIDF for our corpus

# %%
os.chdir('C:/Users/Jason/Documents/Data Science/Spring 2020/Text Analytics/final_project/DS5001-Text-Analytics/Tables')
TOKEN = pd.read_csv('TOKEN.csv')

# %% [markdown]
# ### Reading in the data and preprocessing

# %%
TOKEN.sample(20, random_state=2887)
# Out:
#          book_id  vol_num  chap_num  recp_num  para_num  sent_num  token_num  \
# 1002620    54568        2        16     157.0         1         3         10
# 702288     28681        2         8       0.0        12         0         29
# 325684      9938        3       156     269.0         1         1         27
# 113804      9936        2        30      84.0         0         6          5
# 747960     28681        3        24      18.0        52         0         12
# 268429      9937        5       208     408.0         0         4          0
# 1034432    54568        2        29     289.0         7         1         52
# 281432      9938        1         6      19.0         0         3         14
# 30538       9935        2        51     135.0         0         4         25
# 886083     28681        5        37      37.0        32         0          6
# 699094     28681        2         6       0.0        24         1          7
# 63861       9935        4       150     274.0         1         1         46
# 877272     28681        4        34      31.0        28         3         13
# 1094623    61185        0        10       0.0        28         0         20
# 522782     12519        0         5      64.0         1         0          5
# 545906     12519        0        11     266.0         1         0         95
# 456271      9939        4       197     517.0         9         2          3
# 55595       9935        3       130     240.0         0         1          3
# 892012     29519        0         2      20.0         1         4         13
# 7302        9935        1        11      34.0         0         2         35
#
#                  pos_tuple  pos token_str term_str
# 1002620     ('time', 'NN')   NN      time     time
# 702288        ('up', 'RP')   RP        up       up
# 325684       ('all', 'DT')   DT       all      all
# 113804          (',', ',')    ,         ,      NaN
# 747960        ('No', 'UH')   UH        No       no
# 268429   ('Besides', 'IN')   IN   Besides  besides
# 1034432    ('aside', 'RB')   RB     aside    aside
# 281432     ('serve', 'VB')   VB     serve    serve
# 30538       ('that', 'IN')   IN      that     that
# 886083     ('light', 'JJ')   JJ     light    light
# 699094         ('7', 'CD')   CD         7        7
# 63861           (',', ',')    ,         ,      NaN
# 877272          (';', ':')    :         ;      NaN
# 1094623       ('by', 'IN')   IN        by       by
# 522782      ('take', 'VB')   VB      take     take
# 545906       ('the', 'DT')   DT       the      the
# 456271        ('to', 'TO')   TO        to       to
# 55595       ('AND', 'NNP')  NNP       AND      and
# 892012   ('lobster', 'NN')   NN   lobster  lobster
# 7302       ('clear', 'JJ')   JJ     clear    clear

# %%
TOKEN.shape
# Out:
# (1130904, 11)

# %%
LIB = pd.read_csv('LIB.csv')
LIB
# Out:
#     book_id author_last                                      author_full  \
# 0      9935       WIDAS  Woman's Institute of Domestic Arts and Sciences
# 1      9936       WIDAS  Woman's Institute of Domestic Arts and Sciences
# 2      9937       WIDAS  Woman's Institute of Domestic Arts and Sciences
# 3      9938       WIDAS  Woman's Institute of Domestic Arts and Sciences
# 4      9939       WIDAS  Woman's Institute of Domestic Arts and Sciences
# 5     10582     Bradley                                    Alice Bradley
# 6     12519     Randolf                                    Mary Randolph
# 7     15464     Goudiss                                    Alice Bradley
# 8     19077        Hill                              Janet McKenzie Hill
# 9     24205      Murrey                                 Thomas J. Murrey
# 10    24542      Murrey                                 Thomas J. Murrey
# 11    25007      Murrey                                 Thomas J. Murrey
# 12    28681   Kitchiner                                William Kitchiner
# 13    29519      Hooper                                      Mary Hooper
# 14    32472        Lusk                                      Graham Lusk
# 15    34107   Santiagoe                                 Daniel Santiagoe
# 16    38464      Murrey                                 Thomas J. Murrey
# 17    53521      Murrey                                 Thomas J. Murrey
# 18    54568      Boland                                   Mary A. Boland
# 19    61185       Payne                                 Arthur Gay Payne
#
#     book_year                                      book_title  \
# 0        1923    Woman's Institute Library of Cookery, Vol. 1
# 1        1923    Woman's Institute Library of Cookery, Vol. 2
# 2        1923    Woman's Institute Library of Cookery, Vol. 3
# 3        1923    Woman's Institute Library of Cookery, Vol. 4
# 4        1923    Woman's Institute Library of Cookery, Vol. 5
# 5        1923                  For Luncheon and Supper Guests
# 6        1860                          The Virginia Housewife
# 7        1918     Foods That Will Win The War And How To Cook
# 8        1909  Salads, Sandwiches and Chafing - Dish Dainties
# 9        1885                              Breakfast Dainties
# 10       1885                                    Fifty Salads
# 11       1884                                     Fifty Soups
# 12       1830     The Cook's Oracle; and Housekeeper's Manual
# 13       1892                          Nelson's Home Comforts
# 14       1918                                Food in War Time
# 15       1887                      The Curry Cook's Assistant
# 16       1891                           Tempting Curry Dishes
# 17       1888                                Oysters and Fish
# 18       1893                   A Handbook of Invalid Cooking
# 19       1877                Common - Sense Papers on Cookery
#
#                                         book_file
# 0          Cookbooks/WIDAS1923_WILCV01_pg9935.txt
# 1          Cookbooks/WIDAS1923_WILCV02_pg9936.txt
# 2          Cookbooks/WIDAS1923_WILCV03_pg9937.txt
# 3          Cookbooks/WIDAS1923_WILCV04_pg9938.txt
# 4          Cookbooks/WIDAS1923_WILCV05_pg9939.txt
# 5          Cookbooks/Bradley1923_FLSG_pg10582.txt
# 6   Cookbooks/Randolf1860_VAHousewife_pg12519.txt
# 7           Cookbooks/Goudiss1918_War_pg15464.txt
# 8            Cookbooks/Hill1909_SSCDD_pg19077.txt
# 9          Cookbooks/Murrey1885_Bfast_pg24205.txt
# 10        Cookbooks/Murrey1885_Salads_pg24542.txt
# 11         Cookbooks/Murrey1884_Soups_pg25007.txt
# 12        Cookbooks/Kitchiner1830_TCO_pg28681.txt
# 13           Cookbooks/Hooper1892_NHC_pg29519.txt
# 14             Cookbooks/Lusk1918_War_pg32472.txt
# 15      Cookbooks/Santiagoe1887_Curry_pg34107.txt
# 16         Cookbooks/Murrey1891_Curry_pg38464.txt
# 17          Cookbooks/Murrey1888_Fish_pg53521.txt
# 18       Cookbooks/Boland1893_Invalid_pg54568.txt
# 19           Cookbooks/Payne1877_CSPC_pg61185.txt

# %%
#merging in the library table since it contains the book year
TOKEN1 = pd.merge(TOKEN,LIB,on='book_id', how="inner")
TOKEN1.sample(10)
# Out:
#          book_id  vol_num  chap_num  recp_num  para_num  sent_num  token_num  \
# 268201      9937        5       207     406.0         0         5         15
# 1056659    54568        2        35     348.0        49         0         54
# 790875     28681        3        27      21.0        88         1         15
# 427349      9939        3       109     332.0         0         2         19
# 20762       9935        2        28      93.0         0         5         25
# 702560     28681        2         8       0.0        16         1         31
# 693499     28681        1         5       0.0       110         2         52
# 628086     19077        2        18     266.0         0         0         25
# 1009090    54568        2        18     177.0         1         1         33
# 209041      9937        2        57     107.0         1         0          2
#
#                    pos_tuple  pos token_str  term_str author_last  \
# 268201         ('can', 'MD')   MD       can       can       WIDAS
# 1056659           (',', ',')    ,         ,       NaN      Boland
# 790875     ('thready', 'JJ')   JJ   thready   thready   Kitchiner
# 427349     ('purpose', 'NN')   NN   purpose   purpose       WIDAS
# 20762           ('be', 'VB')   VB        be        be       WIDAS
# 702560         ('the', 'DT')   DT       the       the   Kitchiner
# 693499      ('tickle', 'VB')   VB    tickle    tickle   Kitchiner
# 628086   ('kneadeth', 'VBP')  VBP  kneadeth  kneadeth        Hill
# 1009090           ('.', '.')    .         .       NaN      Boland
# 209041        ('rule', 'NN')   NN      rule      rule       WIDAS
#
#                                              author_full  book_year  \
# 268201   Woman's Institute of Domestic Arts and Sciences       1923
# 1056659                                   Mary A. Boland       1893
# 790875                                 William Kitchiner       1830
# 427349   Woman's Institute of Domestic Arts and Sciences       1923
# 20762    Woman's Institute of Domestic Arts and Sciences       1923
# 702560                                 William Kitchiner       1830
# 693499                                 William Kitchiner       1830
# 628086                               Janet McKenzie Hill       1909
# 1009090                                   Mary A. Boland       1893
# 209041   Woman's Institute of Domestic Arts and Sciences       1923
#
#                                              book_title  \
# 268201     Woman's Institute Library of Cookery, Vol. 3
# 1056659                   A Handbook of Invalid Cooking
# 790875      The Cook's Oracle; and Housekeeper's Manual
# 427349     Woman's Institute Library of Cookery, Vol. 5
# 20762      Woman's Institute Library of Cookery, Vol. 1
# 702560      The Cook's Oracle; and Housekeeper's Manual
# 693499      The Cook's Oracle; and Housekeeper's Manual
# 628086   Salads, Sandwiches and Chafing - Dish Dainties
# 1009090                   A Handbook of Invalid Cooking
# 209041     Woman's Institute Library of Cookery, Vol. 3
#
#                                         book_file
# 268201     Cookbooks/WIDAS1923_WILCV03_pg9937.txt
# 1056659  Cookbooks/Boland1893_Invalid_pg54568.txt
# 790875    Cookbooks/Kitchiner1830_TCO_pg28681.txt
# 427349     Cookbooks/WIDAS1923_WILCV05_pg9939.txt
# 20762      Cookbooks/WIDAS1923_WILCV01_pg9935.txt
# 702560    Cookbooks/Kitchiner1830_TCO_pg28681.txt
# 693499    Cookbooks/Kitchiner1830_TCO_pg28681.txt
# 628086       Cookbooks/Hill1909_SSCDD_pg19077.txt
# 1009090  Cookbooks/Boland1893_Invalid_pg54568.txt
# 209041     Cookbooks/WIDAS1923_WILCV03_pg9937.txt

# %%
#adding in a feature for the rough period of time
per = []
for i in range(len(TOKEN1)):
    if TOKEN1.book_year[i] >= 1900: #creating three groups -- those after 1900, those in the late 1800s, and those in the mid 1800s
        value = '1900s'
    elif TOKEN1.book_year[i] >= 1875:
        value = "late1800s"
    else:
        value = "mid1800s"
    per.append(value)
TOKEN1['period'] = per
TOKEN1.sample(10)
# Out:
#          book_id  vol_num  chap_num  recp_num  para_num  sent_num  token_num  \
# 385100      9939        1        39      66.0         2         2         14
# 764570     28681        3        25      20.0        12         0         53
# 338922      9938        3       206     346.0         0         2         20
# 1058130    54568        2        36     354.0         6         2          0
# 854338     28681        3        30      26.0        45         0          3
# 145035      9936        5       102     217.0         0         3         32
# 864530     28681        4        33      30.0        75         0          1
# 53563       9935        3       121     231.0         0         1          7
# 38240       9935        3        70     156.0         0         2         11
# 1067548    61185        0         2       0.0         9         2         12
#
#                   pos_tuple  pos token_str term_str author_last  \
# 385100           ('.', '.')    .         .      NaN       WIDAS
# 764570        ('it', 'PRP')  PRP        it       it   Kitchiner
# 338922       ('kind', 'NN')   NN      kind     kind       WIDAS
# 1058130  ('Browned', 'VBN')  VBN   Browned  browned      Boland
# 854338     ('saving', 'NN')   NN    saving   saving   Kitchiner
# 145035       ('food', 'NN')   NN      food     food       WIDAS
# 864530    ('pounds', 'NNS')  NNS    pounds   pounds   Kitchiner
# 53563       ('wheat', 'NN')   NN     wheat    wheat       WIDAS
# 38240      ('found', 'VBN')  VBN     found    found       WIDAS
# 1067548        ('of', 'IN')   IN        of       of       Payne
#
#                                              author_full  book_year  \
# 385100   Woman's Institute of Domestic Arts and Sciences       1923
# 764570                                 William Kitchiner       1830
# 338922   Woman's Institute of Domestic Arts and Sciences       1923
# 1058130                                   Mary A. Boland       1893
# 854338                                 William Kitchiner       1830
# 145035   Woman's Institute of Domestic Arts and Sciences       1923
# 864530                                 William Kitchiner       1830
# 53563    Woman's Institute of Domestic Arts and Sciences       1923
# 38240    Woman's Institute of Domestic Arts and Sciences       1923
# 1067548                                 Arthur Gay Payne       1877
#
#                                            book_title  \
# 385100   Woman's Institute Library of Cookery, Vol. 5
# 764570    The Cook's Oracle; and Housekeeper's Manual
# 338922   Woman's Institute Library of Cookery, Vol. 4
# 1058130                 A Handbook of Invalid Cooking
# 854338    The Cook's Oracle; and Housekeeper's Manual
# 145035   Woman's Institute Library of Cookery, Vol. 2
# 864530    The Cook's Oracle; and Housekeeper's Manual
# 53563    Woman's Institute Library of Cookery, Vol. 1
# 38240    Woman's Institute Library of Cookery, Vol. 1
# 1067548              Common - Sense Papers on Cookery
#
#                                         book_file     period
# 385100     Cookbooks/WIDAS1923_WILCV05_pg9939.txt      1900s
# 764570    Cookbooks/Kitchiner1830_TCO_pg28681.txt   mid1800s
# 338922     Cookbooks/WIDAS1923_WILCV04_pg9938.txt      1900s
# 1058130  Cookbooks/Boland1893_Invalid_pg54568.txt  late1800s
# 854338    Cookbooks/Kitchiner1830_TCO_pg28681.txt   mid1800s
# 145035     Cookbooks/WIDAS1923_WILCV02_pg9936.txt      1900s
# 864530    Cookbooks/Kitchiner1830_TCO_pg28681.txt   mid1800s
# 53563      Cookbooks/WIDAS1923_WILCV01_pg9935.txt      1900s
# 38240      Cookbooks/WIDAS1923_WILCV01_pg9935.txt      1900s
# 1067548      Cookbooks/Payne1877_CSPC_pg61185.txt  late1800s

# %% [markdown]
# ### Defining the TFIDF Function

# %%
def TFIDF(TOKEN, OHCO='book', count_method='n', tf_method='sum', idf_method='standard', term_type='term_str'): 

    #specifying the term type
    TOKEN = TOKEN[~TOKEN.term_str.isna()] #removing blank term_str
    stemmer1 = PorterStemmer()
    TOKEN['stem'] = TOKEN.term_str.apply(stemmer1.stem) #adding stems
    print('Term Type: ', term_type)

    
    #specifying the bag size, customized to our text
    OHCO1 = ['period', 'book_year','book_id', 'vol_num','chap_num', 'recp_num','para_num', 'sent_num', 'token_num']
    sentence = OHCO1[:8]
    paragraph = OHCO1[:7]
    recipe = OHCO1[:6]
    chapter = OHCO1[:5]
    volume = OHCO1[:4]
    book = OHCO1[:3]
    book_year = OHCO1[:2]
    period = OHCO1[:1]
    if OHCO == 'chapter':
        bag = chapter
    elif OHCO == 'sentence':
        bag = sentence
    elif OHCO == 'paragraph':
        bag = paragraph
    elif OHCO == 'book':
        bag = book
    elif OHCO == 'recipe':
        bag = recipe
    elif OHCO == 'volume':
        bag = volume
    elif OHCO == 'period':
        bag = period
    elif OHCO == 'book_year':
        bag = book_year
    print('Bag Level: ', OHCO)

    #creating the document-term matrix
    BOW = TOKEN.groupby(bag+[term_type]).term_str.count()\
    .to_frame().rename(columns={'term_str':'n'})
    BOW['c'] = BOW.n.astype('bool').astype('int')
    DTCM = BOW[count_method].unstack().fillna(0).astype('int')
    print('Count method: ', count_method)

    #specifying the TF method and calculating TF
    if tf_method == 'sum':
        TF = DTCM.T / DTCM.T.sum()
    elif tf_method == 'max':
        TF = DTCM.T / DTCM.T.max()
    elif tf_method == 'log':
        TF = np.log10(1 + DTCM.T)
    elif tf_method == 'raw':
        TF = DTCM.T
    elif tf_method == 'double_norm':
        TF = DTCM.T / DTCM.T.max()
        TF = tf_norm_k + (1 - tf_norm_k) * TF[TF > 0] 
    elif tf_method == 'binary':
        TF = DTCM.T.astype('bool').astype('int')
    print('TF method: ', tf_method)
   
    #calculating DF and TFIDF
    DF = DTCM[DTCM > 0].count()
    N = DTCM.shape[0]
    
    if idf_method == 'standard':
        IDF = np.log10(N / DF)
    elif idf_method == 'max':
        IDF = np.log10(DF.max() / DF) 
    elif idf_method == 'smooth':
        IDF = np.log10((1 + N) / (1 + DF)) + 1 
    print('IDF method: ', idf_method)    

    TF = TF.T
    TFIDF = TF * IDF
    
    return TFIDF

# %% [markdown]
# ### Running the function with a bag of book
#
# Note: I defined all of the arguments (even though it's not required by the function) just so it would be clear what specifications we used.

# %%
TFIDF_book = TFIDF(TOKEN=TOKEN1, OHCO='book', count_method='n', tf_method='sum', idf_method='standard', term_type='term_str')
# Out:
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Term Type:  term_str
# Bag Level:  book
# Count method:  n
# TF method:  sum
# IDF method:  standard

# %%
TFIDF_book.sum().sort_values(ascending=False).head(30)

#looking at the top 30 words in our corpus by TFIDF -- interesting that we got some numbers in there!
# Out:
# term_str
# 12               0.010532
# 1                0.009640
# curry            0.008969
# teaspoon         0.008843
# tablespoons      0.007332
# tsp              0.006166
# antonini         0.005320
# cup              0.005207
# 14               0.005086
# c                0.004756
# p                0.004661
# nelson           0.004642
# tb               0.004391
# smith            0.003997
# metabolism       0.003850
# tablespoon       0.003781
# teaspoons        0.003732
# syrup            0.003596
# j                0.003342
# 4                0.003191
# stuffs           0.003133
# blazer           0.003121
# till             0.003036
# calories         0.002940
# madras           0.002933
# teaspoonful      0.002919
# foods            0.002870
# gill             0.002839
# 3                0.002827
# tablespoonful    0.002749
# dtype: float64

# %% [markdown]
# ### Running TFIDF with a bag of recipe

# %%
TFIDF_recp = TFIDF(TOKEN=TOKEN1, OHCO='recipe', count_method='n', tf_method='sum', idf_method='standard', term_type='term_str')
# Out:
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Term Type:  term_str
# Bag Level:  recipe
# Count method:  n
# TF method:  sum
# IDF method:  standard

# %%
TFIDF_recp.sum().sort_values(ascending=False).head(30)
#looking at TFIDF by recipe
# Out:
# term_str
# 1         25.807714
# is        18.428777
# cup       18.059645
# it        17.931239
# them      17.303845
# be        16.731512
# are       16.177557
# c         16.170029
# 2         16.137305
# milk      16.041030
# water     15.611171
# 12        15.214541
# as        15.057910
# add       15.005058
# the       14.919713
# sugar     14.177607
# butter    13.546018
# for       13.489683
# that      13.470927
# cream     13.446396
# of        13.203503
# or        13.176509
# with      13.100030
# salt      13.007485
# they      12.901848
# a         12.451291
# flour     12.357812
# salad     12.221847
# to        11.958100
# sauce     11.916914
# dtype: float64

# %% [markdown]
# ### Running TFIDF with a bag of book period

# %%
TFIDF_timeperiod = TFIDF(TOKEN1, OHCO="period", count_method='n', tf_method='sum', idf_method='standard', term_type='term_str')
# Out:
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Term Type:  term_str
# Bag Level:  period
# Count method:  n
# TF method:  sum
# IDF method:  standard

# %%
TFIDF_timeperiod.sum().sort_values(ascending=False).head(30)
# Out:
# term_str
# tsp               0.000777
# obs               0.000682
# tb                0.000554
# flavor            0.000335
# teaspoon          0.000299
# nelson            0.000291
# sirup             0.000282
# amount            0.000252
# teaspoonful       0.000228
# tablespoons       0.000191
# yelks             0.000184
# nb                0.000172
# shown             0.000168
# etc               0.000162
# tablespoonful     0.000156
# tablespoon        0.000149
# qt                0.000145
# color             0.000142
# canned            0.000141
# colour            0.000135
# protein           0.000133
# yelk              0.000132
# yolks             0.000127
# saltspoon         0.000122
# tablespoonfuls    0.000120
# tamis             0.000115
# ¼                 0.000109
# mayonnaise        0.000108
# drachm            0.000108
# savoury           0.000106
# dtype: float64

# %% [markdown]
# ### Writing to CSV

# %%
TFIDF_book.to_csv('TFIDF_book.csv')
TFIDF_recp.to_csv('TFIDF_recp.csv')
TFIDF_timeperiod.to_csv('TFIDF_timeperiod.csv')
